# %% [markdown]
# # ADS - Network analysis module homework

# %% [markdown]
# ## Task (World airports).
# ### Q1.
# Find the network connected components, report their number and the sizes.
#
# ### Q2.
# In the largest connected component find and report (print a list of city names and centrality scores) top 10 airports by each centrality metric (degree, betweenneass, closeness, pagerank with $alpha=0.85$).
#
# ### Q3.
# Find maximum and average network distance of the shortest path (number of edges, regardless of size) between all pairs of the airports from the largest connected component. Visualize the shortest path of the maximum length.
#
# ### Q4.
# Find average network distance among the top 100 airports by pagerank (with $alpha=0.85$) within the largest connected component
#
# ### Q5.
# Partition the entire network using Combo algorithm, visualize the partition

# %%
#add necessary libraries
import networkx as nx #library supporting networks
import matplotlib.pyplot as plt #plotting
import pandas as pd
import numpy as np
import scipy.stats as stat
#make sure plots are embedded into the notebook
# %pylab inline
import statsmodels.formula.api as smf
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
path = 'https://raw.githubusercontent.com/CUSP-ADS2024/Data/main/'
cities = pd.read_csv(path + 'citiesTable.csv' , index_col=0 )
cities.head()
# Out:
#              country name most active airport  long. most active airport  \
# city name
# London     United Kingdom            Heathrow                     -0.103
# Chicago     United States  Chicago Ohare Intl                    -87.842
# Paris              France   Charles De Gaulle                      2.916
# Moscow             Russia          Domododevo                     38.510
# Shanghai            China              Pudong                    122.342
#
#            lat. most active airport  number of routes  \
# city name
# London                       51.795              1984
# Chicago                      42.631              1406
# Paris                        49.021              1254
# Moscow                       55.681              1179
# Shanghai                     31.238              1115
#
#            number incoming flights  number outcoming flights  \
# city name
# London                         993                       992
# Chicago                        705                       702
# Paris                          626                       629
# Moscow                         589                       591
# Shanghai                       560                       556
#
#            number incoming domestic flights  \
# city name
# London                                   57
# Chicago                                 526
# Paris                                    68
# Moscow                                  231
# Shanghai                                357
#
#            number outcoming domestic flights  \
# city name
# London                                    57
# Chicago                                  523
# Paris                                     68
# Moscow                                   231
# Shanghai                                 353
#
#            number incoming international flights  \
# city name
# London                                       936
# Chicago                                      179
# Paris                                        558
# Moscow                                       358
# Shanghai                                     203
#
#            number outcoming international flights  only domestic flights  \
# city name
# London                                        934                      0
# Chicago                                       178                      0
# Paris                                         560                      0
# Moscow                                        359                      0
# Shanghai                                      202                      0
#
#            average distance  max. distance
# city name
# London                 3228          11153
# Chicago                2328          12416
# Paris                  3367          11652
# Moscow                 2772          10054
# Shanghai               2235          12245

# %%
#now read the links
links = pd.read_csv('https://raw.githubusercontent.com/CUSP-ADS2024/Data/main/citiesToCities.csv?token=GHSAT0AAAAAACMXBT22UYFOM7AYHZQZKLJ4ZPH3KEQ', index_col=None )
links.head()
# Out:
#    departure city  long. departure (decimal)  lat. departure (decimal)  \
# 0       Sao Paulo                    -46.116                   -23.054
# 1  Rio De Janeiro                    -42.740                   -22.682
# 2         Beijing                    116.974                    40.133
# 3    Johannesburg                     28.410                   -25.566
# 4        Honolulu                   -157.871                    21.531
#
#   departure country    arrival city  long. departure (decimal).1  \
# 0            Brazil  Rio De Janeiro                      -42.740
# 1            Brazil       Sao Paulo                      -46.116
# 2             China        Shanghai                      122.342
# 3      South Africa       Cape Town                       19.002
# 4     United States           Tokyo                      140.643
#
#    lat. departure (decimal).1 arrival country  number of routes  distance
# 0                     -22.682          Brazil                18       348
# 1                     -23.054          Brazil                18       348
# 2                      31.238           China                18      1100
# 3                     -33.942    South Africa                16      1299
# 4                      36.274           Japan                16      6103

# %%
#create the graph (assume connections are symmatric directionality)
Flights=nx.Graph()
Flights.add_nodes_from(cities.index)
EN=len(links.index)
edgelist=[(links['departure city'][j],links['arrival city'][j]) for j in range(EN)]
Flights.add_edges_from(edgelist)

# %% [markdown]
# ### Q1.
# Find the network connected components, report their number and the sizes.

# %%
cc=list(nx.connected_components(Flights))

# %%
len(cc)
# Out:
# 4

# %%
cc
# Out:
# [{'Oujda',
#   'Joensuu',
#   'Bydgoszcz',
#   'Egegik',
#   'Nunapitchuk',
#   'Providence',
#   'Benin',
#   'Wakkanai',
#   'Gerona',
#   'Fergana',
#   'Mekoryuk',
#   'Aracaju',
#   'Yangon',
#   'Rodez',
#   'Al-Jawf',
#   'El Fasher',
#   'Surgut',
#   'Moosonee',
#   'Mombasa',
#   'Marion',
#   'La Coruna',
#   'Misawa',
#   'New Bedford',
#   'Sachs Harbour',
#   'Lannion',
#   'Limbang',
#   'Lopez',
#   'Quincy',
#   'Duesseldorf',
#   'Padang',
#   'Myeik',
#   'Praya',
#   'Noumea',
#   'Kapuskasing',
#   'Iliamna',
#   'Tindouf',
#   'Bronnoysund',
#   'Bentota',
#   'Sacramento',
#   'Kuopio',
#   'False Pass',
#   'Salerno',
#   'Green Bay',
#   'Nikolayev',
#   'Krasnoyarsk',
#   'Wuhai',
#   'Rafha',
#   'Nicosia',
#   'Orebro',
#   'Stavanger',
#   'Bushehr',
#   'Holguin',
#   'Vladivostok',
#   'Chibougamau',
#   'Bintulu',
#   'Tiree',
#   'Brussels',
#   'Teesside',
#   'Catumbela',
#   'Alderney',
#   'Inverness',
#   'Tokushima',
#   'Port Moresby',
#   'Semarang',
#   'Weifang',
#   'Oradea',
#   'Lille',
#   'Wolf Point',
#   'Casablanca',
#   'East Midlands',
#   'Manzini',
#   'Bukhara',
#   'St. John',
#   'Mudgee',
#   'Puerto Jimenez',
#   'Eastmain River',
#   'Craig Cove',
#   'International Falls',
#   'Colville Lake',
#   'Zarzaitine',
#   'Tacloban',
#   'Whitehorse',
#   'Islay',
#   'Masai Mara',
#   'Trabzon',
#   'Cat Lake',
#   'Pingtung',
#   'Westsound',
#   'Peoria',
#   'Omaha',
#   'Erechim',
#   'Dong Hoi',
#   'Kasos',
#   'Maumere',
#   'Memmingen',
#   'Pointe-noire',
#   'La Chorrera',
#   "Dillon's Bay",
#   'Samara',
#   'Calama',
#   'Yichang',
#   'Sandakan',
#   'Abilene',
#   'Vienna',
#   'Yuncheng',
#   'Sfax',
#   'Pleiku',
#   'Salta',
#   'Oklahoma City',
#   'Jabalpur',
#   'Bucharest',
#   'Solo City',
#   'Milan',
#   'Thorne Bay',
#   'San Julian',
#   'Hyderabad',
#   'Whangarei',
#   'Billund',
#   'Flint',
#   'Korla',
#   'Porlamar',
#   'West Tinian',
#   'Indore',
#   'Annaba',
#   'Castries',
#   'Kochi',
#   'Kisumu',
#   'Tomsk',
#   'Kostanay',
#   'Juba',
#   'Santiago De Cuba',
#   'LaCrosse',
#   'Santa Maria (island)',
#   'Erbil',
#   'Nanyuki',
#   'Aleppo',
#   'Semiplatinsk',
#   'Livingstone',
#   'Chokurdah',
#   'Ouargla',
#   'Vijayawada',
#   'Colombo',
#   'Kirkwall',
#   'Kuito',
#   'Cabinda',
#   'Grenoble',
#   'Kalgoorlie',
#   'Dresden',
#   'Bratsk',
#   'Nanaimo',
#   'Makale',
#   'Russian Mission',
#   'Huangshan',
#   'Rio Branco',
#   'Naha',
#   'Gallivare',
#   'Kegaska',
#   'Navoi',
#   'Saltillo',
#   'Vancouver',
#   'Jodhpur',
#   'Talara',
#   'Rodriguez Island',
#   'Baku',
#   'Fort Chipewyan',
#   'Bocas Del Toro',
#   'Salina',
#   'Toksook Bay',
#   'Santander',
#   'Dnepropetrovsk',
#   'Rapid City',
#   'Kuching',
#   'Tamanrasset',
#   'Sivas',
#   'Tabriz',
#   'Selawik',
#   'Makkovik',
#   'Tucurui',
#   'Hibbing',
#   'Popayan',
#   'Madinah',
#   'Takaroa',
#   'Borlange',
#   'Neiva',
#   'Kano',
#   'Chadron',
#   'Jayapura',
#   'Crescent City',
#   'Fagernes',
#   'Perm',
#   'Bacolod',
#   'Gizo',
#   'The Pas',
#   'Rygge',
#   'Thandwe',
#   'Dillingham',
#   'Tenerife',
#   'Bandar Abbas',
#   'Teresina',
#   'Emerald',
#   'Andros Town',
#   'Dangriga',
#   'Westport',
#   'Kalamata',
#   'Uberaba',
#   'La Fortuna/San Carlos',
#   'Arctic Village',
#   'Bloomington',
#   'Hami',
#   'Tak',
#   'Rondonopolis',
#   'El-baha',
#   'Fakarava',
#   'Papa Westray',
#   'Iquique',
#   'Ranchi',
#   'Caldas Novas',
#   'Caen',
#   'Quibdo',
#   'Marudi',
#   'Cincinnati',
#   'Bisha',
#   'Williston',
#   'Togiak Village',
#   'Sidney',
#   'Uummannaq',
#   'Rochester',
#   'Paulatuk',
#   'Red Devil',
#   'Tiruchirappalli',
#   'Djerba',
#   'Quelimane',
#   'Eau Claire',
#   'Quepos',
#   'Yancheng',
#   'Djibouti',
#   'Montpellier',
#   'Santiago',
#   'Karaganda',
#   'Zhijiang',
#   'Elfin Cove',
#   'Gamètì',
#   'Morgantown',
#   'Pikangikum',
#   'Ancona',
#   'Wellington',
#   'Uberlandia',
#   'Sukhothai',
#   'Chu Lai',
#   'Ujung Pandang',
#   'Linkoeping',
#   'Chengdu',
#   'Cheboksary',
#   'Nassau',
#   'Lajes (terceira Island)',
#   'Ambon',
#   'Puerto Lempira',
#   'Walaha',
#   'Victoria',
#   'Wonju',
#   'Porto Alegre',
#   'Tuguegarao',
#   'Tehran',
#   'Beslan',
#   'Manihi',
#   'Healy',
#   'Scarborough',
#   'Mora',
#   'Alliance',
#   'Prescott',
#   'Pohang',
#   'Tucson',
#   'Orsta-Volda',
#   'Bethel',
#   'Guadalajara',
#   'Roadtown/beef Island',
#   'Tanna',
#   'Jimma',
#   'Madurai',
#   'Halmstad',
#   'Calgary',
#   'Mangaia Island',
#   'Haiphong',
#   'Porto',
#   'Sogndal',
#   'Menongue',
#   'Cruzeiro do Sul',
#   'Nikolai',
#   'Manta',
#   'Bourgas',
#   'Quetta',
#   'Yamagata',
#   'Ciudad Obregon',
#   'Accra',
#   'Jujuy',
#   'Canberra',
#   'Jijiga',
#   'Wassau',
#   'Kwangju',
#   'Aurillac',
#   'Vail',
#   'Birjand',
#   'Sanikiluaq',
#   'Tlemcen',
#   'Missoula',
#   'Bombay',
#   'Agartala',
#   'Ufa',
#   'Nanchang',
#   'Hakodate',
#   'Santorini',
#   'Eugene',
#   'Christchurch',
#   'Port Sudan',
#   'Cotonou',
#   'Caracas',
#   'Brainerd',
#   'Huai An',
#   'Medicine Hat',
#   'Nuevo Laredo',
#   'Bergerac',
#   'Wanxian',
#   'Sao Paulo de Olivenca',
#   'Santa Cruz De La Palma',
#   'PARKERSBURG',
#   'Punta Gorda',
#   'Ishigaki',
#   'Syktyvkar',
#   'Nan',
#   'Porto Santo',
#   'Bismarck',
#   'Orenburg',
#   'Altamira',
#   'Oranjestad',
#   'Texarkana',
#   'Port Angeles',
#   'Tarija',
#   'Governador Valadares',
#   'Budapest',
#   'Svalbard',
#   'Vorkuta',
#   'Valledupar',
#   'Guayaquil',
#   'Sao Jose Do Rio Preto',
#   'Loei',
#   'Dickinson',
#   'Maragheh',
#   'Flin Flon',
#   'Dammam',
#   'Guayaramerín',
#   'Bangor',
#   'Fera Island',
#   'Donetsk',
#   'Kone',
#   'Kasigluk',
#   'Fresno',
#   'Aarhus',
#   'Comodoro Rivadavia',
#   'Monrovia',
#   'Sao Vicente Island',
#   'Marquette',
#   'Modesto',
#   'Hoskins',
#   'Bointo',
#   'Luang Namtha',
#   'San Vincente De Caguan',
#   'Bugulma',
#   'Cuernavaca',
#   'Whyalla',
#   'Columbia',
#   'Tununak',
#   'Charlieville',
#   'Hangzhou',
#   'Mianyang',
#   'Xiangfan',
#   'Sarnia',
#   'Coolangatta',
#   'Alta Floresta',
#   'Trapani',
#   'Maroua',
#   'Manley Hot Springs',
#   'Barquisimeto',
#   'Valdivia',
#   'Lahania-kapalua',
#   'Baracoa Playa',
#   'Rosario',
#   'Sinop',
#   'Burgos',
#   'Toowoomba',
#   'Hao Island',
#   'Walla Walla',
#   'Narathiwat',
#   'Sondrestrom',
#   'Enfidha',
#   'Marsa Alam',
#   'Lijiang',
#   'Kuujjuarapik',
#   'Mount Isa',
#   'Dubrovnik',
#   'Eday',
#   'Liverpool',
#   'Tbilisi',
#   'Akron',
#   'Port Said',
#   'Torino',
#   'Sulaymaniyah',
#   'Turbat',
#   'Malanje',
#   'Timisoara',
#   'Chongqing',
#   'Lubango',
#   'Chernovtsk',
#   'Barinas',
#   'Cebu',
#   'Coari',
#   'Dothan',
#   'Dodge City',
#   'Niigata',
#   'Sitia',
#   'Wuxi',
#   'Blagoveschensk',
#   'Honiara',
#   'Khorram Abad',
#   'Taiyuan',
#   'Jammu',
#   'Nuquí',
#   'Tokyo',
#   'Leh',
#   'Andoya',
#   'Tyler',
#   'Youngstown',
#   'Narvik',
#   'Tame',
#   'Villahermosa',
#   'Stokmarknes',
#   'Des Moines',
#   'Beziers',
#   'Charleroi',
#   'Port Hedland',
#   'Kunsan',
#   'Krasnodar',
#   'Xilinhot',
#   'Tresco',
#   'Aupaluk',
#   'Pucallpa',
#   'Butte',
#   'Bobo-dioulasso',
#   'Port Hardy',
#   'Gillam',
#   'Iquitos',
#   'Ambler',
#   'Atqasuk',
#   'Gillette',
#   'Nakhon Phanom',
#   'Laamu Atoll',
#   'Marrakech',
#   'Surabaya',
#   'Bima',
#   'Qeqertarsuaq Airport',
#   'Fort Smith',
#   'Macapa',
#   'Roanoke VA',
#   'Ekwok',
#   'Fort-de-france',
#   'Quaqtaq',
#   'Keffallinia',
#   'Porto Seguro',
#   'Waskaganish',
#   'Southampton',
#   'Binghamton',
#   'Dayton',
#   'Asahikawa',
#   'Dili',
#   'Koliganek',
#   'Buffalo',
#   'Lihue',
#   'Minacu',
#   'Antananarivo',
#   'Bahar Dar',
#   'Sabzevar',
#   'Quesnel',
#   'Gunnison',
#   'Trondheim',
#   'Kuusamo',
#   'Mont-Tremblant',
#   'Melbourne',
#   'Quinhagak',
#   'Ghardaia',
#   'Anaa',
#   'Tachina',
#   'Westerland',
#   'Mountain Village',
#   'Moenjodaro',
#   'Perth',
#   'Mauke Island',
#   'Rabat',
#   'Villavicencio',
#   'Poznan',
#   'Long Seridan',
#   'Fukuoka',
#   'Rørvik',
#   'Campbell River',
#   'Port Williams',
#   'Porbandar',
#   'Amsterdam',
#   'Londolovit',
#   'Valera',
#   'Brisbane',
#   'Petrozavodsk',
#   'Mulu',
#   'Kandahar',
#   'Manchester NH',
#   'Grayling',
#   'Zarafshan',
#   'Calcutta',
#   'Conson',
#   'Gheshm',
#   'Maio',
#   'Bellingham',
#   'Aberdeen',
#   'Sarasota',
#   'Luxemburg',
#   'Mitu',
#   'Avalon',
#   'Tin City',
#   'Saarbruecken',
#   'Harare',
#   'Broome',
#   'Tanana',
#   'North Bay',
#   'Valdosta',
#   'Lorient',
#   'Stavropol',
#   'Pokhara',
#   'Round Lake',
#   'Gaberone',
#   'Bahias Dehuatulco',
#   'Huahine Island',
#   'Constanta',
#   'Vieques Island',
#   'Twin Hills',
#   'Maun',
#   'Zihuatanejo',
#   'Gyumri',
#   'Esquel',
#   'Bario',
#   'Kona',
#   'Amritsar',
#   'Upernavik',
#   'Haines',
#   'Chifeng',
#   'Chios',
#   'Santa Fe',
#   "Lutselk'e",
#   'Campinas',
#   'Karlovy Vary',
#   'Formosa',
#   'Trang',
#   'Cleveland',
#   'Victoria Falls',
#   'Kralendijk',
#   'Lagos',
#   'Luderitz',
#   'Grand Island',
#   'Nuernberg',
#   'Valladolid',
#   'Tupelo',
#   'Kuressaare',
#   'Tours',
#   'Pescara',
#   'Poplar Hill',
#   "Coff's Harbour",
#   'Ilheus',
#   'Mpacha',
#   'Zhanjiang',
#   'Granada',
#   'Armenia',
#   'Kulyab',
#   'Paraparaumu',
#   'Jiamusi',
#   'Ipota',
#   'Escanaba',
#   'Ketapang',
#   'Del Rio',
#   'Ely',
#   'Karratha',
#   'Trelew',
#   'Malabo',
#   'Zhuhai',
#   'Sokoto',
#   'Kirov',
#   'Kithira',
#   'Tagbilaran',
#   'Rigolet',
#   'Yuma',
#   'Zamboanga',
#   'Kwethluk',
#   'Greensboro',
#   'Alor Setar',
#   'Isfahan',
#   'Lamen Bay',
#   'Mytilini',
#   'Lyon',
#   'Barrow',
#   'Rangiroa',
#   'Oslo',
#   'Kalibo',
#   'Ust Kamenogorsk',
#   'Yonaguni Jima',
#   'Cali',
#   'Clarksburg',
#   "Val D'or",
#   'Kagoshima',
#   'Copiapo',
#   'Manhattan',
#   'Mitiaro Island',
#   'Golfito',
#   'Chimoio',
#   'Noyabrsk',
#   'Fort Frances',
#   'Basse Terre',
#   'Split',
#   'Asheville',
#   'Kerteh',
#   'St. Martin',
#   'Pentecost Island',
#   'Sachigo Lake',
#   'Amboseli National Park',
#   'Quebec',
#   'Sylhet Osmani',
#   'McCook',
#   'Alta',
#   'Las Palmas',
#   'Red Lake',
#   'Bojnourd',
#   'Mahajanga',
#   'Hanamaki',
#   'Tuy Hoa',
#   'Iles De La Madeleine',
#   'Ibaraki',
#   'Newburgh',
#   'Mount Hagen',
#   'Sambava',
#   'Seattle',
#   'Deline',
#   'Cucuta',
#   'Exeter',
#   'Tumling Tar',
#   'Liping',
#   'Deering',
#   'Hassi-messaoud',
#   'Hailey',
#   'Vagar',
#   'Genoa',
#   'Kobe',
#   'Nemiscau',
#   'Kruunupyy',
#   'Sverdlovsk',
#   'Telluride',
#   'Anchorage',
#   'Plovdiv',
#   'La Macarena',
#   'Fargo',
#   'Key West',
#   'Alicante',
#   'Toledo',
#   'Brich Creek',
#   'Bearskin Lake',
#   'Springfield',
#   'Shreveport',
#   'Rundu',
#   'Gulfport',
#   'Osorno',
#   'Pisa',
#   'Norwich',
#   'Ozamis',
#   'Goiania',
#   'Auckland',
#   'Waikabubak-Sumba Island',
#   'Oaxaca',
#   'Georgetown',
#   'Parintins',
#   'Guayana',
#   'Pemba',
#   'Lancaster',
#   'Vineyard Haven MA',
#   'Belize',
#   'Udaipur',
#   'Londonderry',
#   'Beaumont',
#   'Al-Ula',
#   'Rajahmundry',
#   'Udon Thani',
#   'Yopal',
#   'Bacau',
#   'Phrae',
#   'Choiseul Bay',
#   'Kuwait',
#   'Jambi',
#   'Malaga',
#   'Izumo',
#   'Palembang',
#   'Elista',
#   'Kemorovo',
#   'Kzyl-Orda',
#   'Ciudad Juarez',
#   'Baise',
#   'Figari',
#   'Jining',
#   'Bukoba',
#   'Anelghowhat',
#   'Hiva-oa',
#   'Pula',
#   'Juliaca',
#   'Doncaster,Sheffield',
#   "Dead Man's Cay",
#   'Haa Dhaalu Atoll',
#   'Atoifi',
#   'Kramfors',
#   'Yanji',
#   'Mosjoen',
#   'Maues',
#   'Cap Haitien',
#   'Atyrau',
#   'Agatti Island',
#   'Bloemfontein',
#   'Carlsbad',
#   'Austin TX',
#   'Tuktoyaktuk',
#   'Imphal',
#   'Sioux Falls',
#   'College Station',
#   'Du Bois',
#   'Allahabad',
#   'Tongoa Island',
#   'Malindi',
#   'Asuncion',
#   'Adak Island',
#   'Milos',
#   'Lampang',
#   'Vernal',
#   'Antwerp',
#   'Webequie',
#   'Can Tho',
#   'Kulu',
#   'Cayenne',
#   'Gizan',
#   'Golovin',
#   'Willemstad',
#   'Bandar Mahshahr',
#   'Cortez',
#   'Okinawa',
#   'Freetown',
#   'Pago Pago',
#   'Chitral',
#   'Aspen',
#   'Kiev',
#   'Milano',
#   'Samarkand',
#   'Petropavlovsk',
#   'Lynchburg',
#   'Colombia',
#   'San Luis Obispo',
#   'San Angelo',
#   'Cologne',
#   'Lake Charles',
#   'Fuerteventura',
#   'Carcassonne',
#   'Ogdensburg',
#   'Campina Grande',
#   'Bujumbura',
#   'Stony River',
#   'Lodz',
#   'Hollis',
#   'Parsabad',
#   'Takoradi',
#   'Forli',
#   'Tefe',
#   'Shishmaref',
#   'Abuja',
#   'Haugesund',
#   'Latakia',
#   'Minot',
#   'Hagfors',
#   'Sanya',
#   'South Bend',
#   'Timika',
#   'Virac',
#   'Chita',
#   'Kerry',
#   'Dijon',
#   'Dawadmi',
#   'Magnetiogorsk',
#   'Kharkov',
#   'Jeddah',
#   'Elat',
#   'Nashville',
#   'Arcata CA',
#   'Kaitaia',
#   'Jinan',
#   'Chevak',
#   'Katowice',
#   'Salt Lake City',
#   'Merida',
#   'Sharurah',
#   'Pardubice',
#   'Hue',
#   'Puerto Escondido',
#   'Kamuela',
#   'Townsville',
#   'Fernando Do Noronha',
#   'Cape Dorset',
#   'Igiugig',
#   'Biskra',
#   'Kerman',
#   'Khabarovsk',
#   'Helsinki',
#   'Phucat',
#   'Abidjan',
#   'Barreiras',
#   'Dushanbe',
#   'Uluru',
#   'Adrar',
#   'Catamarca',
#   'Ludhiaha',
#   'Greenville',
#   'Shimla',
#   'Taiz',
#   'Cacador',
#   'Gisborne',
#   'Port-vila',
#   'Kotlik',
#   'Hoedspruit',
#   'Farmington',
#   'Apartadó',
#   'Ganzhou',
#   'Karpathos',
#   'Yeosu',
#   'Stornoway',
#   'Pakse',
#   'Mae Hong Son',
#   'Boise',
#   'Nouadhibou',
#   'La Grande Riviere',
#   'Wagga Wagga',
#   'Gaziantep',
#   'Abu Dhabi',
#   'Sofia',
#   'Muan',
#   'Khajuraho',
#   'Kalamazoo',
#   'Östersund',
#   'Sheridan',
#   'Killeen',
#   'Torsby',
#   'Gustavia',
#   'Porto Velho',
#   'Evansville',
#   'Bharatpur',
#   'Mexicali',
#   'St. Paul Island',
#   'Portland',
#   'El Aaiún',
#   'Fort Albany',
#   'Humera',
#   'Aswan',
#   'Taraken',
#   'Lhok Seumawe-Sumatra Island',
#   'Mcallen',
#   'Sao Luis',
#   'Tartu-ulenurme',
#   'Mashhad',
#   'Ironwood',
#   'Puvirnituq',
#   'Sundsvall',
#   'Basel-Mulhouse-Freiburg',
#   'Quito',
#   'Torreon',
#   'Gafsa',
#   'Louisville',
#   'Varanasi',
#   'Nicoya',
#   'Denpasar',
#   'Monterrey',
#   'White Plains',
#   'Tauranga',
#   'Cauayan',
#   'Fort Mcmurray',
#   'Sitka',
#   'Colorado Springs',
#   'Tirana',
#   'Saurimo',
#   'Tanjung Manis',
#   'Jerez',
#   'Goose Bay',
#   'Old Harbor',
#   'Peawanuck',
#   'Deer Lake',
#   'Cancun',
#   'Surat Thani',
#   'Chuathbaluk',
#   'Temuco',
#   'Madras',
#   'Masterton',
#   'Vasteras',
#   'Wroclaw',
#   'Augsburg',
#   'Phu Quoc',
#   'Athens',
#   'Mount Pleasant',
#   'Al Ghaidah Intl',
#   'Zadar',
#   'Moa',
#   'Abadan',
#   'Manokwari',
#   'Chandragarhi',
#   'Chapeco',
#   'Yazd',
#   'Kilimanjaro',
#   'Ulan Bator',
#   'Multan',
#   'Ponta Delgada',
#   'Rockford',
#   'Muskrat Dam',
#   'Contadora Island',
#   'Skardu',
#   'Laage',
#   'Nome',
#   'Matei',
#   'Quanzhou',
#   'Tengchong',
#   'Viedma',
#   'Olbia',
#   'Ablow',
#   'Geneva',
#   'Friday Harbor',
#   'Patos de Minas',
#   'George',
#   'La Tabatière',
#   'Nukus',
#   'Rimini',
#   'San Pedro',
#   'Nagoya',
#   'Ovda',
#   'Pickle Lake',
#   'Tenakee Springs',
#   'Friedrichshafen',
#   'Puebla',
#   'Allentown',
#   'New Stuyahok',
#   'Lonorore',
#   'Dawei',
#   'Sochi',
#   'Nanjing',
#   'Skagway',
#   'Plaisance',
#   'Wrangell',
#   'Santa Clara',
#   'Amarillo',
#   'Blackpool',
#   'Ninbo',
#   'Dominica',
#   'Tanjung Pinang',
#   'Grand Forks',
#   'Imperial',
#   'Yinchuan',
#   'Latrobe',
#   'Detroit',
#   'Mcgrath',
#   'Agadir',
#   'Basco',
#   'Inuvik',
#   'Namangan',
#   'Musoma',
#   'Wainwright',
#   'Bakalalan',
#   'Mananara',
#   'Nabire',
#   'Worland',
#   'Little Rock',
#   'Lloydminster',
#   'Ballalae',
#   'Makhachkala',
#   'Paros',
#   'Chihuahua',
#   'Tabatinga',
#   'Islip',
#   'Canaima',
#   'Navegantes',
#   'Helgoland',
#   'Inukjuak',
#   'Kingscote',
#   'Hasvik',
#   'Coimbatore',
#   'Vinh',
#   'Birmingham',
#   'Dalian',
#   'La Paz',
#   'Arauca',
#   'Nyala',
#   ...},
#  {'Akutan', 'Nikolski', 'Unalaska'},
#  {'Boulder City', 'Grand Canyon West'},
#  {'Block Island', 'Leixlip'}]

# %% [markdown]
# ### Q2.
# In the largest connected component find and report (print a list of city names and centrality scores) top 10 airports by each centrality metric (degree, betweenneass, closeness, pagerank with $alpha=0.85$).

# %%
max_cc = max(cc,key=len)

# %%
max_cc_graph = nx.Graph()
max_cc_graph.add_nodes_from(max_cc)
max_cc_graph.add_edges_from(edgelist)

# %%
max_cc_graph

# %%
#output top tn centrality scores, given the dictionary d
def topdict(d,tn):
    ind=sorted(d, key=d.get, reverse=True)
    for i in range(0,tn):
       print('{0}|{1} - {2}'.format(i+1, ind[i], d[ind[i]]))

# %%
mc1=dict(nx.degree(max_cc_graph))
ind1=topdict(mc1,10)
# Out:
# 1|London - 311
# 2|Paris - 267
# 3|Frankfurt - 232
# 4|Moscow - 229
# 5|Amsterdam - 208
# 6|Atlanta - 208
# 7|Chicago - 199
# 8|Beijing - 184
# 9|Istanbul - 181
# 10|Dallas-fort Worth - 181

# %%
mc2 = nx.betweenness_centrality(max_cc_graph)
ind2=topdict(mc2,10)
# Out:
# 1|London - 0.09034228164817283
# 2|Anchorage - 0.08177900060547015
# 3|Paris - 0.07747744448398268
# 4|Moscow - 0.06075222333964134
# 5|Chicago - 0.05786272504019246
# 6|Frankfurt - 0.05426812317265427
# 7|Seattle - 0.05247273837944525
# 8|Dubai - 0.046225264730113756
# 9|Tokyo - 0.04563994105465244
# 10|Toronto - 0.04510249041924883

# %%
mc3 = nx.closeness_centrality(max_cc_graph)
ind4=topdict(mc3,10)
# Out:
# 1|London - 0.4223634613466614
# 2|Frankfurt - 0.4165055203725343
# 3|Paris - 0.4153998050047715
# 4|Amsterdam - 0.4084935977492648
# 5|New York - 0.3995989790885954
# 6|Toronto - 0.3954005059740856
# 7|Los Angeles - 0.3950852364676611
# 8|Chicago - 0.39180500848960853
# 9|Dubai - 0.391701766063129
# 10|Newark - 0.38873122442719005

# %%
mc4 = nx.pagerank(max_cc_graph,0.85)
ind4=topdict(mc4,10)
# Out:
# 1|London - 0.006643690212771939
# 2|Moscow - 0.006394773861081004
# 3|Paris - 0.006281190416793756
# 4|Atlanta - 0.005005165152212129
# 5|Frankfurt - 0.004791527894478359
# 6|Chicago - 0.004698791227789344
# 7|Dallas-fort Worth - 0.0046822210655662515
# 8|Denver - 0.004615583755208125
# 9|Houston - 0.004388076110471844
# 10|Amsterdam - 0.004302029752645577

# %% [markdown]
# ### Q3.
# Find maximum and average network distance of the shortest path (number of edges, regardless of size) between all pairs of the airports from the largest connected component. Visualize the shortest path of the maximum length.

# %% [markdown]
# ### From the largest connected component

# %%
max_cc_graph

# %%
CityPos={c:(cities['long. most active airport'][c],cities['lat. most active airport'][c])
         for c in cities.index}

# %%
sp = dict(nx.shortest_path_length(max_cc_graph))

# %%
diameter=0; s=0; n=0;
for i in sp.items():
    for j in i[1].items():
        if j[1]>diameter:
            s += j[1]
            n += 1

print('Average distance is:', s/n)
# Out:
# Average distance is: 3.9398398584324226

# %%
diameter=0; i0=0; j0=0;
for i in sp.items():
    for j in i[1].items():
        if j[1]>diameter:
            diameter=j[1]
            i0=i[0]
            j0=j[0]
print('{0} - {1} : {2}'.format(i0,j0,diameter))
# Out:
# Red Devil - Port Hope Simpson : 12

# %%
def visualize_path(path):
    plt.figure(figsize = (12,6))
    nx.draw(max_cc_graph,pos=CityPos,with_labels=False,arrows=False,node_size=15,style='dotted',edge_color='green')
    x=[CityPos[v][0] for v in path]
    y=[CityPos[v][1] for v in path]
    plt.plot(x,y,'ro-')
    plt.plot([x[0],x[-1]],[y[0],y[-1]],'bs',markersize=10)

# %%
Lpath=nx.shortest_path(max_cc_graph,i0,j0)
visualize_path(Lpath)

# %% [markdown]
# ### From the whole network

# %%
wsp = dict(nx.shortest_path_length(Flights))

# %%
diameter=0; s=0; n=0;
for i in wsp.items():
    for j in i[1].items():
        if j[1]>diameter:
            s += j[1]
            n += 1

print('Average distance is:', s/n)
# Out:
# Average distance is: 3.9398398584324226

# %%
diameter=0; i0=0; j0=0;
for i in wsp.items():
    for j in i[1].items():
        if j[1]>diameter:
            diameter=j[1]
            i0=i[0]
            j0=j[0]
print('{0} - {1} : {2}'.format(i0,j0,diameter))
# Out:
# Peawanuck - Koliganek : 12

# %%
def visualize_path(path):
    plt.figure(figsize = (12,6))
    nx.draw(Flights,pos=CityPos,with_labels=False,arrows=False,node_size=15,style='dotted',edge_color='green')
    x=[CityPos[v][0] for v in path]
    y=[CityPos[v][1] for v in path]
    plt.plot(x,y,'ro-')
    plt.plot([x[0],x[-1]],[y[0],y[-1]],'bs',markersize=10)

# %%
Lpath=nx.shortest_path(Flights,i0,j0)
visualize_path(Lpath)

# %% [markdown]
# ### Q4.
# Find average network distance among the top 100 airports by pagerank (with $alpha=0.85$) within the largest connected component

# %%
mc5 = nx.pagerank(max_cc_graph,0.85)
ind5=topdict(mc5,100)
# Out:
# 1|London - 0.006643690212771939
# 2|Moscow - 0.006394773861081004
# 3|Paris - 0.006281190416793756
# 4|Atlanta - 0.005005165152212129
# 5|Frankfurt - 0.004791527894478359
# 6|Chicago - 0.004698791227789344
# 7|Dallas-fort Worth - 0.0046822210655662515
# 8|Denver - 0.004615583755208125
# 9|Houston - 0.004388076110471844
# 10|Amsterdam - 0.004302029752645577
# 11|Istanbul - 0.00426623716650042
# 12|Beijing - 0.004185690340827128
# 13|Dubai - 0.003929547894784932
# 14|Bangkok - 0.0038550095917917605
# 15|Tokyo - 0.003777909218247712
# 16|New York - 0.0037686561722692856
# 17|Toronto - 0.0036882096329491553
# 18|Shanghai - 0.0036337665696786784
# 19|Los Angeles - 0.003625095070549394
# 20|Minneapolis - 0.0035920396985633547
# 21|Rome - 0.0034847021898968124
# 22|Seoul - 0.0033937222637993353
# 23|Madrid - 0.003377320476599088
# 24|Kuala Lumpur - 0.003323278443519695
# 25|Las Vegas - 0.0033149701116852903
# 26|Newark - 0.0032703782050847977
# 27|Munich - 0.003109582395899543
# 28|Detroit - 0.0030851542260006562
# 29|Washington - 0.003065254196204369
# 30|Singapore - 0.003041345358017611
# 31|Bogota - 0.0030225749647928703
# 32|Miami - 0.003013244501873342
# 33|Charlotte - 0.0030031719946274566
# 34|Stockholm - 0.002932690619202766
# 35|Manila - 0.002873632565362997
# 36|Buenos Aires - 0.0028656391102760467
# 37|Mexico City - 0.0028215117134895535
# 38|Johannesburg - 0.002817116321595396
# 39|Barcelona - 0.0027784643860926726
# 40|Guangzhou - 0.0027735516532843515
# 41|St. Petersburg - 0.0027083671349628826
# 42|Delhi - 0.002668359680555082
# 43|Sao Paulo - 0.002629429490916262
# 44|Seattle - 0.002562255583909767
# 45|Montreal - 0.002559994091846436
# 46|Hong Kong - 0.0025530458451816884
# 47|Athens - 0.0025381914952528643
# 48|Vancouver - 0.002504566297156464
# 49|San Francisco - 0.002475704845463967
# 50|Fort Lauderdale - 0.0024701618275310812
# 51|Philadelphia - 0.0024697846134276356
# 52|Zurich - 0.0024372780846073933
# 53|Bethel - 0.002410813087112629
# 54|Vienna - 0.002408729891625095
# 55|Sydney - 0.0024067841169572923
# 56|Manchester - 0.002400280486134407
# 57|Orlando - 0.002396246365391594
# 58|Phoenix - 0.0023820968974361065
# 59|Anchorage - 0.0023492644648757596
# 60|Boston - 0.0023238752518914825
# 61|Nairobi - 0.0023171456001116818
# 62|Copenhagen - 0.0022951276281067954
# 63|Auckland - 0.002273058752909554
# 64|Salt Lake City - 0.0022615227385779438
# 65|Brussels - 0.002254767694113551
# 66|Milano - 0.0022202589958257067
# 67|Bombay - 0.0021892950688911766
# 68|Doha - 0.0021835975650280628
# 69|Brisbane - 0.0021789701905345063
# 70|Duesseldorf - 0.0021400524504332397
# 71|Papeete - 0.0021245641532196646
# 72|Taipei - 0.002113199649124724
# 73|Lima - 0.0020689403501412324
# 74|Jeddah - 0.0020633249791723557
# 75|Jakarta - 0.00204392248141359
# 76|Riyadh - 0.0020301744949783014
# 77|Cairo - 0.0019645297659284166
# 78|Berlin - 0.0019640124174766017
# 79|Oslo - 0.0019637749957839954
# 80|Fairbanks - 0.0019481434005015187
# 81|Kunming - 0.0019284226717216119
# 82|Lisbon - 0.001926215786057447
# 83|Chengdu - 0.001910206848409848
# 84|Helsinki - 0.0019091040251195182
# 85|San Jose - 0.001900714090806596
# 86|Algier - 0.001899203551967434
# 87|Addis Ababa - 0.0018279709669235809
# 88|Abu Dhabi - 0.0017909694342661175
# 89|Santiago - 0.0017744055883725273
# 90|Panama City - 0.0017699195407870295
# 91|Prague - 0.0017597937165391157
# 92|Rio De Janeiro - 0.0017454063802304633
# 93|Dublin - 0.0017380291764841952
# 94|Brasilia - 0.0017338125669577344
# 95|Melbourne - 0.0016948401969739655
# 96|Birmingham - 0.0016737433508911426
# 97|Kiev - 0.0016717518253203032
# 98|Honiara - 0.0016624249968011451
# 99|Cancun - 0.0016623953210336113
# 100|Osaka - 0.0016612649882429991

# %%
subgraph = max_cc_graph.subgraph(ind5)

# Calculate all pairs shortest path lengths
path_lengths = dict(nx.all_pairs_shortest_path_length(subgraph))

# Compute the average distance
total_distance = 0
count = 0
for node, lengths in path_lengths.items():
    for target, distance in lengths.items():
        if node != target:  # Exclude distance to itself
            total_distance += distance
            count += 1

average_distance = total_distance / count if count != 0 else 0
print("Average network distance among the top 100 nodes:", average_distance)

# %%
subgraph

# %% [markdown]
# ### Q5.
# Partition the entire network using Combo algorithm, visualize the partition

# %%
# !pip install pycombo
# !pip install geopandas
# Out:
# Collecting pycombo
#   Using cached pycombo-0.1.7.tar.gz (136 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11<3.0.0,>=2.6.1 (from pycombo)
#   Obtaining dependency information for pybind11<3.0.0,>=2.6.1 from https://files.pythonhosted.org/packages/26/55/e776489172f576b782e616f58273e1f3de56a91004b0d20504169dd345af/pybind11-2.12.0-py3-none-any.whl.metadata
#   Using cached pybind11-2.12.0-py3-none-any.whl.metadata (9.5 kB)
# Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# Building wheels for collected packages: pycombo
#   Building wheel for pycombo (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pycombo (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [125 lines of output]
#       In file included from src/Binder.cpp:1:
#       In file included from /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:45:
#       In file included from /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/attr.h:13:
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/cast.h:446:36: error: member access into incomplete type 'PyFrameObject' (aka '_frame')
#                       "  " + handle(frame->f_code->co_filename).cast<std::string>() +
#                                          ^
#       /Users/fengcharles/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of '_frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       In file included from src/Binder.cpp:1:
#       In file included from /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:45:
#       In file included from /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/attr.h:13:
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/cast.h:448:29: error: member access into incomplete type 'PyFrameObject' (aka '_frame')
#                       handle(frame->f_code->co_name).cast<std::string>() + "\n";
#                                   ^
#       /Users/fengcharles/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of '_frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       In file included from src/Binder.cpp:1:
#       In file included from /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:45:
#       In file included from /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/attr.h:13:
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/cast.h:449:26: error: member access into incomplete type 'PyFrameObject' (aka '_frame')
#                   frame = frame->f_back;
#                                ^
#       /Users/fengcharles/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of '_frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       In file included from src/Binder.cpp:1:
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:2213:49: error: no member named 'frame' in '_ts'
#           PyFrameObject *frame = PyThreadState_Get()->frame;
#                                  ~~~~~~~~~~~~~~~~~~~  ^
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:2214:41: error: member access into incomplete type 'PyFrameObject' (aka '_frame')
#           if (frame && (std::string) str(frame->f_code->co_name) == name &&
#                                               ^
#       /Users/fengcharles/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of '_frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       In file included from src/Binder.cpp:1:
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:2215:14: error: member access into incomplete type 'PyFrameObject' (aka '_frame')
#               frame->f_code->co_argcount > 0) {
#                    ^
#       /Users/fengcharles/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of '_frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       In file included from src/Binder.cpp:1:
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:2218:18: error: member access into incomplete type 'PyFrameObject' (aka '_frame')
#                   frame->f_locals, PyTuple_GET_ITEM(frame->f_code->co_varnames, 0));
#                        ^
#       /Users/fengcharles/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of '_frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       In file included from src/Binder.cpp:1:
#       /private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/include/pybind11/pybind11.h:2218:52: error: member access into incomplete type 'PyFrameObject' (aka '_frame')
#                   frame->f_locals, PyTuple_GET_ITEM(frame->f_code->co_varnames, 0));
#                                                          ^
#       /Users/fengcharles/anaconda3/include/python3.11/pytypedefs.h:22:16: note: forward declaration of '_frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       8 errors generated.
#       Traceback (most recent call last):
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/unixccompiler.py", line 117, in _compile
#           self.spawn(compiler_so + cc_args + [src, '-o', obj] +
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/ccompiler.py", line 910, in spawn
#           spawn(cmd, dry_run=self.dry_run)
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/spawn.py", line 91, in spawn
#           raise DistutilsExecError(
#       distutils.errors.DistutilsExecError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-install-tatzmgn7/pycombo_14c2db4e8b59424f82656f747ea27553/build.py", line 30, in build_extension
#           build_ext.build_extension(self, ext)
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/command/build_ext.py", line 529, in build_extension
#           objects = self.compiler.compile(sources,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/ccompiler.py", line 574, in compile
#           self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/unixccompiler.py", line 120, in _compile
#           raise CompileError(msg)
#       distutils.errors.CompileError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-install-tatzmgn7/pycombo_14c2db4e8b59424f82656f747ea27553/build.py", line 65, in <module>
#           build({})
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-install-tatzmgn7/pycombo_14c2db4e8b59424f82656f747ea27553/build.py", line 48, in build
#           cmd.run()
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-install-tatzmgn7/pycombo_14c2db4e8b59424f82656f747ea27553/build.py", line 24, in run
#           build_ext.run(self)
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/command/build_ext.py", line 340, in run
#           self.build_extensions()
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/pybind11/setup_helpers.py", line 288, in build_extensions
#           _build_ext.build_extensions(self)
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/command/build_ext.py", line 449, in build_extensions
#           self._build_extensions_serial()
#         File "/Users/fengcharles/anaconda3/lib/python3.11/distutils/command/build_ext.py", line 474, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-install-tatzmgn7/pycombo_14c2db4e8b59424f82656f747ea27553/build.py", line 37, in build_extension
#           raise BuildFailed(f"Could not compile C++ extension: {e}")
#       BuildFailed: Could not compile C++ extension: command '/usr/bin/clang' failed with exit code 1
#       Traceback (most recent call last):
#         File "/Users/fengcharles/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/fengcharles/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/fengcharles/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/poetry/core/masonry/api.py", line 58, in build_wheel
#           return WheelBuilder.make_in(
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/poetry/core/masonry/builders/wheel.py", line 88, in make_in
#           wb.build(target_dir=directory)
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/poetry/core/masonry/builders/wheel.py", line 123, in build
#           self._build(zip_file)
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/poetry/core/masonry/builders/wheel.py", line 172, in _build
#           self._run_build_script(self._package.build_script)
#         File "/private/var/folders/qp/9y56mfxx3zq2c_cjbvf9xg_w0000gn/T/pip-build-env-z5p6at2e/overlay/lib/python3.11/site-packages/poetry/core/masonry/builders/wheel.py", line 262, in _run_build_script
#           subprocess.check_call([self.executable.as_posix(), build_script])
#         File "/Users/fengcharles/anaconda3/lib/python3.11/subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['/Users/fengcharles/anaconda3/bin/python', 'build.py']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pycombo
# Failed to build pycombo
# ERROR: Could not build wheels for pycombo, which is required to install pyproject.toml-based projects
# Requirement already satisfied: geopandas in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (0.14.1)
# Requirement already satisfied: fiona>=1.8.21 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.4.0 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.8.0 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/fengcharles/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (1.24.3)

# %%
import pycombo # combo community detection package
import networkx as nx #library supporting networks
import matplotlib.pyplot as plt #plotting
import pandas as pd
import numpy as np
import scipy.stats as stat
from scipy import optimize
#make sure plots are embedded into the notebook
# %pylab inline
import statsmodels.formula.api as smf
import os
from networkx.algorithms import community
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import pycombo # combo community detection package
#       2 import networkx as nx #library supporting networks
#       3 import matplotlib.pyplot as plt #plotting
#
# ModuleNotFoundError: No module named 'pycombo'

# %%
PCFlights, PCFlightsMod = pycombo.execute(Flights, max_communities = 0) #keep number of communities flexible
PCFlightsMod

# %%
def visualizePartition(G,partition,pos):
  N=len(G.nodes())
  s=4+4*int(log10(N))
  plt.figure(figsize=(12,6))
  PN=max(partition.values())
  my_cmap = matplotlib.cm.hsv(np.linspace(0,1,PN+1)) #create a colormap for a given number of communities
  c=[]
  for n in G.nodes():
    c.append(1.0*partition[n]/PN)
  nx.draw(G,pos=pos,with_labels=False,node_size=15,node_color=c,style='dotted',edge_color='green')

# %%
visualizePartition (Flights,PCFlights,CityPos)
